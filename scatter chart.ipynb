# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
d = pd.read_csv('C:/Users/santy/Desktop/sealevel.csv')

# %%
year = d['Year']
sea_levels = d['CSIRO Adjusted Sea Level']
plt.scatter(year,sea_levels)
plt.xlabel('Year')
plt.ylabel('Sea Level')
plt.title('Rise in Sealevel')
plt.show()
